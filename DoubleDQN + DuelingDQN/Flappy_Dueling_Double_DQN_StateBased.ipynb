# %% [markdown]
# # Flappy Bird — Dueling Double DQN (State-Based, Gymnasium)
# This notebook implements a **state-based** Dueling Double DQN for `FlappyBird-v0` from **flappy-bird-gymnasium**.
# It includes:
# - Dueling DQN network architecture
# - Double DQN training logic
# - Replay buffer with `push()` and `sample()`
# - Reward shaping and survival/progress bonuses
# - Slower epsilon decay
# - Gradient clipping and step-based target updates
# - Model saving/loading and optional gameplay recording
#
# Run on GPU (Colab/VS Code) for faster training. Adjust `episodes` for quick tests.

# %%
# Install dependencies (uncomment to run in Colab / if packages are missing)
#pip install gymnasium flappy-bird-gymnasium torch numpy matplotlib imageio[ffmpeg] tqdm --quiet
#pip install moviepy

# %%
import random
import os
import math
import time
import numpy as np
import gymnasium as gym
import flappy_bird_gymnasium
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
from IPython.display import Video, display
import imageio
import matplotlib.pyplot as plt
import cv2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# Device: cuda

# %%
# Dueling DQN (state-based)
class DuelingDQN(nn.Module):
    def __init__(self, state_size, action_size, hidden=128):
        super(DuelingDQN, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.value_head = nn.Linear(hidden, 1)
        self.adv_head = nn.Linear(hidden, action_size)

    def forward(self, x):
        # Accept numpy arrays or torch tensors
        if isinstance(x, np.ndarray):
            x = torch.from_numpy(x).float().to(device)
        x = x.float().to(device)
        if x.dim() == 1:
            x = x.unsqueeze(0)
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        value = self.value_head(h)
        adv = self.adv_head(h)
        q = value + (adv - adv.mean(dim=1, keepdim=True))
        return q

# %%
# Replay buffer
class ReplayBuffer:
    def __init__(self, capacity=50000):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        states = np.asarray(states, dtype=np.float32)
        next_states = np.asarray(next_states, dtype=np.float32)
        return (
            torch.from_numpy(states).to(device),
            torch.tensor(actions, dtype=torch.long, device=device),
            torch.tensor(rewards, dtype=torch.float32, device=device),
            torch.from_numpy(next_states).to(device),
            torch.tensor(dones, dtype=torch.float32, device=device),
        )

    def __len__(self):
        return len(self.buffer)

# %%
# Utilities: stacking, action selection, save/load
def stack_frames(buffer_deque, new_state, k):
    if len(buffer_deque) == 0:
        for _ in range(k):
            buffer_deque.append(new_state)
    else:
        buffer_deque.append(new_state)
    return np.concatenate(list(buffer_deque), axis=-1)

def select_action(q_net, state, action_space, epsilon):
    if random.random() < epsilon:
        return action_space.sample()
    state_t = torch.from_numpy(np.array(state, dtype=np.float32)).unsqueeze(0).to(device)
    with torch.no_grad():
        qvals = q_net(state_t)
        return int(torch.argmax(qvals, dim=1).item())

def save_model(net, path):
    torch.save(net.state_dict(), path)

def load_model(net, path):
    net.load_state_dict(torch.load(path, map_location=device))

# %%
# Training function (Dueling + Double DQN, state-based) with improved stability
def train_dueling_double_dqn_state(
    env_name='FlappyBird-v0',
    episodes=2000,
    gamma=0.99,
    lr=5e-5,
    batch_size=128,
    memory_size=100000,
    epsilon_start=1.0,
    epsilon_end=0.05,
    epsilon_decay=0.9998,      # slower decay
    target_update_steps=4000,  # update target network by training steps
    reward_scale=5.0,
    survival_bonus=0.02,
    progress_coef=0.001,
    grad_clip=10.0,
    frame_stack_k=3,
    save_path='best_flappy_dqn_state.pth',
    record_video=False,
    video_path='flappy_state_trained.mp4'
):
    env = gym.make(env_name)
    obs, _ = env.reset()
    base_dim = len(obs)
    state_dim = base_dim * frame_stack_k
    action_dim = env.action_space.n

    q_net = DuelingDQN(state_dim, action_dim).to(device)
    target_net = DuelingDQN(state_dim, action_dim).to(device)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = optim.Adam(q_net.parameters(), lr=lr)
    memory = ReplayBuffer(memory_size)

    epsilon = epsilon_start
    train_steps = 0
    rewards_history = []
    best_avg = -1e9
    moving_avg_window = 100

    for ep in range(1, episodes+1):
        obs, _ = env.reset()
        frame_deque = deque(maxlen=frame_stack_k)
        state = stack_frames(frame_deque, obs, frame_stack_k)
        total_reward = 0.0
        done = False

        prev_h_dist = None
        while not done:
            action = select_action(q_net, state, env.action_space, epsilon)
            next_obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            env_r = float(reward)
            try:
                h_dist = float(next_obs[2])
            except Exception:
                h_dist = None

            # compute progress bonus if horizontal distance exists
            progress_bonus = 0.0
            if prev_h_dist is not None and h_dist is not None:
                # if bird gets closer to the pipe horizontally, that's progress (prev_h_dist - h_dist positive)
                progress_bonus = progress_coef * max(0.0, prev_h_dist - h_dist)

            prev_h_dist = h_dist if h_dist is not None else prev_h_dist

            # survival bonus small positive each step
            shaped = env_r * reward_scale + survival_bonus + progress_bonus
            # clip shaped reward to keep updates stable
            shaped = float(max(-2.0, min(2.0, shaped)))

            frame_deque.append(next_obs)
            next_state = np.concatenate(list(frame_deque), axis=-1)

            memory.push(state, action, shaped, next_state, float(done))
            state = next_state
            total_reward += env_r  # log original environment reward (not shaped)

            # training step
            if len(memory) >= batch_size:
                states_b, actions_b, rewards_b, next_states_b, dones_b = memory.sample(batch_size)

                # current Q values
                q_values = q_net(states_b).gather(1, actions_b.unsqueeze(1)).squeeze(1)

                # Double DQN: action selection by online net, evaluation by target net
                with torch.no_grad():
                    next_actions = q_net(next_states_b).argmax(dim=1, keepdim=True)
                    next_q = target_net(next_states_b).gather(1, next_actions).squeeze(1)
                    target_q = rewards_b + gamma * next_q * (1.0 - dones_b)

                loss = F.mse_loss(q_values, target_q)
                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(q_net.parameters(), grad_clip)
                optimizer.step()

                train_steps += 1
                if train_steps % target_update_steps == 0:
                    target_net.load_state_dict(q_net.state_dict())

            # decay epsilon per step slowly
            epsilon = max(epsilon_end, epsilon * epsilon_decay)

        rewards_history.append(total_reward)
        # moving average
        if len(rewards_history) >= moving_avg_window:
            avg_recent = float(np.mean(rewards_history[-moving_avg_window:]))
        else:
            avg_recent = float(np.mean(rewards_history))

        # save best model based on moving average
        if len(rewards_history) >= moving_avg_window and avg_recent > best_avg:
            best_avg = avg_recent
            save_model(q_net, save_path)

        if ep % 10 == 0 or ep == 1:
            print(f"Episode {ep}/{episodes} | Reward: {total_reward:.2f} | Avg{moving_avg_window}: {avg_recent:.2f} | Epsilon: {epsilon:.4f} | Buffer: {len(memory)}")

    env.close()

    if record_video:
        video_path = os.path.join("videos", video_path)

        env = gym.make(env_name, render_mode='rgb_array')
        writer = imageio.get_writer(video_path, fps=30)

        num_episodes = 10
        max_steps = 500

        for ep in range(1, num_episodes + 1):
            obs, _ = env.reset()
            frame_deque = deque(maxlen=frame_stack_k)
            state = stack_frames(frame_deque, obs, frame_stack_k)
            done = False
            step = 0

            while not done and step < max_steps:
                step += 1
                action = select_action(q_net, state, env.action_space, 0.0)
                obs, _, terminated, truncated, _ = env.step(action)
                done = terminated or truncated
                frame_deque.append(obs)
                state = np.concatenate(list(frame_deque), axis=-1)
                frame = env.render()

                # Overlay text showing episode number
                frame = cv2.putText(
                    frame.copy(),
                    f"Episode {ep}",
                    (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1.2,
                    (255, 255, 255),
                    3,
                    cv2.LINE_AA,
                )
                writer.append_data(frame)

            print(f"Recorded episode {ep}/{num_episodes}")

        writer.close()
        env.close()
        print(f"Saved compiled video to {video_path}")

    return q_net, rewards_history

# %%
model, rewards = train_dueling_double_dqn_state(
    env_name='FlappyBird-v0',
    episodes=10000,
    gamma=0.99,
    lr=5e-5,
    batch_size=128,
    memory_size=100000,
    epsilon_start=1.0,
    epsilon_end=0.05,
    epsilon_decay=0.9998,
    target_update_steps=4000,
    reward_scale=5.0,
    survival_bonus=0.02,
    progress_coef=0.001,
    grad_clip=10.0,
    frame_stack_k=3,
    save_path='best_flappy_dqn_state.pth',
    record_video=True,
    video_path='flappy_state_trained.mp4'
)
# Out:
# Episode 1/10000 | Reward: -8.10 | Avg100: -8.10 | Epsilon: 0.9900 | Buffer: 50
# Episode 10/10000 | Reward: -8.70 | Avg100: -7.92 | Epsilon: 0.9048 | Buffer: 500
# Episode 20/10000 | Reward: -8.10 | Avg100: -7.83 | Epsilon: 0.8187 | Buffer: 1000
# Episode 30/10000 | Reward: -8.10 | Avg100: -7.58 | Epsilon: 0.7408 | Buffer: 1500
# Episode 40/10000 | Reward: -6.90 | Avg100: -7.29 | Epsilon: 0.6703 | Buffer: 2000
# Episode 50/10000 | Reward: -7.50 | Avg100: -7.31 | Epsilon: 0.6065 | Buffer: 2500
# Episode 60/10000 | Reward: -6.30 | Avg100: -7.00 | Epsilon: 0.5488 | Buffer: 3000
# Episode 70/10000 | Reward: -8.70 | Avg100: -6.85 | Epsilon: 0.4966 | Buffer: 3500
# Episode 80/10000 | Reward: -4.50 | Avg100: -6.80 | Epsilon: 0.4493 | Buffer: 4000
# Episode 90/10000 | Reward: -4.50 | Avg100: -6.51 | Epsilon: 0.4065 | Buffer: 4500
# Episode 100/10000 | Reward: -2.10 | Avg100: -6.43 | Epsilon: 0.3678 | Buffer: 5000
# Episode 110/10000 | Reward: -0.90 | Avg100: -6.22 | Epsilon: 0.3328 | Buffer: 5500
# Episode 120/10000 | Reward: -0.90 | Avg100: -5.96 | Epsilon: 0.3012 | Buffer: 6000
# Episode 420/10000 | Reward: 0.90 | Avg100: -1.61 | Epsilon: 0.0500 | Buffer: 21292
# Episode 430/10000 | Reward: -2.70 | Avg100: -1.50 | Epsilon: 0.0500 | Buffer: 21871
# Episode 440/10000 | Reward: -0.90 | Avg100: -1.52 | Epsilon: 0.0500 | Buffer: 22393
# Episode 450/10000 | Reward: 0.80 | Avg100: -1.24 | Epsilon: 0.0500 | Buffer: 22937
# Episode 460/10000 | Reward: 1.70 | Avg100: -1.16 | Epsilon: 0.0500 | Buffer: 23474
# Episode 470/10000 | Reward: -2.60 | Avg100: -1.03 | Epsilon: 0.0500 | Buffer: 24113
# Episode 480/10000 | Reward: -5.10 | Avg100: -0.91 | Epsilon: 0.0500 | Buffer: 24644
# Episode 490/10000 | Reward: 0.80 | Avg100: -0.85 | Epsilon: 0.0500 | Buffer: 25233
# Episode 500/10000 | Reward: 1.10 | Avg100: -0.91 | Epsilon: 0.0500 | Buffer: 25791
# Episode 510/10000 | Reward: -9.30 | Avg100: -0.80 | Epsilon: 0.0500 | Buffer: 26347
# Episode 520/10000 | Reward: 2.70 | Avg100: -0.98 | Epsilon: 0.0500 | Buffer: 26867
# Episode 530/10000 | Reward: -0.90 | Avg100: -1.06 | Epsilon: 0.0500 | Buffer: 27410
# Episode 540/10000 | Reward: 2.30 | Avg100: -1.07 | Epsilon: 0.0500 | Buffer: 27919
# Episode 550/10000 | Reward: -0.90 | Avg100: -1.14 | Epsilon: 0.0500 | Buffer: 28502
# Episode 560/10000 | Reward: -0.80 | Avg100: -1.23 | Epsilon: 0.0500 | Buffer: 29123
# Episode 570/10000 | Reward: 0.40 | Avg100: -1.29 | Epsilon: 0.0500 | Buffer: 29639
# Episode 580/10000 | Reward: 1.50 | Avg100: -1.36 | Epsilon: 0.0500 | Buffer: 30158
# Episode 590/10000 | Reward: -8.70 | Avg100: -1.35 | Epsilon: 0.0500 | Buffer: 30700
# Episode 600/10000 | Reward: 5.00 | Avg100: -1.27 | Epsilon: 0.0500 | Buffer: 31220
# Episode 610/10000 | Reward: 2.70 | Avg100: -1.50 | Epsilon: 0.0500 | Buffer: 31767
# Episode 620/10000 | Reward: 1.60 | Avg100: -1.44 | Epsilon: 0.0500 | Buffer: 32418
# Episode 630/10000 | Reward: -0.90 | Avg100: -1.19 | Epsilon: 0.0500 | Buffer: 32967
# Episode 640/10000 | Reward: -0.30 | Avg100: -1.16 | Epsilon: 0.0500 | Buffer: 33541
# Episode 650/10000 | Reward: 2.90 | Avg100: -1.30 | Epsilon: 0.0500 | Buffer: 34049
# Episode 660/10000 | Reward: -0.90 | Avg100: -1.43 | Epsilon: 0.0500 | Buffer: 34619
# Episode 670/10000 | Reward: -0.90 | Avg100: -1.51 | Epsilon: 0.0500 | Buffer: 35179
# Episode 680/10000 | Reward: 2.60 | Avg100: -1.67 | Epsilon: 0.0500 | Buffer: 35711
# Episode 690/10000 | Reward: -0.90 | Avg100: -1.82 | Epsilon: 0.0500 | Buffer: 36256
# Episode 700/10000 | Reward: -0.90 | Avg100: -2.09 | Epsilon: 0.0500 | Buffer: 36800
# Episode 710/10000 | Reward: -9.30 | Avg100: -2.09 | Epsilon: 0.0500 | Buffer: 37304
# Episode 720/10000 | Reward: -8.10 | Avg100: -2.15 | Epsilon: 0.0500 | Buffer: 37893
# Episode 730/10000 | Reward: 1.00 | Avg100: -2.39 | Epsilon: 0.0500 | Buffer: 38430
# Episode 740/10000 | Reward: 1.50 | Avg100: -2.37 | Epsilon: 0.0500 | Buffer: 38963
# Episode 750/10000 | Reward: 2.10 | Avg100: -2.18 | Epsilon: 0.0500 | Buffer: 39479
# Episode 760/10000 | Reward: -0.90 | Avg100: -2.00 | Epsilon: 0.0500 | Buffer: 40044
# Episode 770/10000 | Reward: 2.90 | Avg100: -1.85 | Epsilon: 0.0500 | Buffer: 40572
# Episode 780/10000 | Reward: -9.30 | Avg100: -1.93 | Epsilon: 0.0500 | Buffer: 41078
# Episode 790/10000 | Reward: -0.90 | Avg100: -1.67 | Epsilon: 0.0500 | Buffer: 41586
# Episode 800/10000 | Reward: -6.90 | Avg100: -1.78 | Epsilon: 0.0500 | Buffer: 42088
# Episode 810/10000 | Reward: 3.10 | Avg100: -1.72 | Epsilon: 0.0500 | Buffer: 42598
# Episode 820/10000 | Reward: -0.20 | Avg100: -1.58 | Epsilon: 0.0500 | Buffer: 43137
# Episode 830/10000 | Reward: 2.10 | Avg100: -1.42 | Epsilon: 0.0500 | Buffer: 43659
# Episode 840/10000 | Reward: -0.90 | Avg100: -1.29 | Epsilon: 0.0500 | Buffer: 44190
# Episode 850/10000 | Reward: 2.30 | Avg100: -1.42 | Epsilon: 0.0500 | Buffer: 44708
# Episode 860/10000 | Reward: 0.90 | Avg100: -1.41 | Epsilon: 0.0500 | Buffer: 45210
# Episode 870/10000 | Reward: -4.50 | Avg100: -1.22 | Epsilon: 0.0500 | Buffer: 45717
# Episode 880/10000 | Reward: -0.90 | Avg100: -1.18 | Epsilon: 0.0500 | Buffer: 46226
# Episode 890/10000 | Reward: 3.00 | Avg100: -1.18 | Epsilon: 0.0500 | Buffer: 46766
# Episode 900/10000 | Reward: -8.10 | Avg100: -0.88 | Epsilon: 0.0500 | Buffer: 47277
# Episode 910/10000 | Reward: -8.70 | Avg100: -0.82 | Epsilon: 0.0500 | Buffer: 47786
# Episode 920/10000 | Reward: -0.90 | Avg100: -1.02 | Epsilon: 0.0500 | Buffer: 48303
# Episode 930/10000 | Reward: 0.90 | Avg100: -0.99 | Epsilon: 0.0500 | Buffer: 48852
# Episode 940/10000 | Reward: 3.10 | Avg100: -0.92 | Epsilon: 0.0500 | Buffer: 49367
# Episode 950/10000 | Reward: -0.90 | Avg100: -0.94 | Epsilon: 0.0500 | Buffer: 49867
# Episode 960/10000 | Reward: -0.00 | Avg100: -0.97 | Epsilon: 0.0500 | Buffer: 50453
# Episode 970/10000 | Reward: -9.30 | Avg100: -1.13 | Epsilon: 0.0500 | Buffer: 50956
# Episode 980/10000 | Reward: 2.90 | Avg100: -0.93 | Epsilon: 0.0500 | Buffer: 51479
# Episode 990/10000 | Reward: -0.90 | Avg100: -0.70 | Epsilon: 0.0500 | Buffer: 51985
# Episode 1000/10000 | Reward: 0.30 | Avg100: -0.44 | Epsilon: 0.0500 | Buffer: 52485
# Episode 1010/10000 | Reward: 0.70 | Avg100: -0.30 | Epsilon: 0.0500 | Buffer: 53015
# Episode 1020/10000 | Reward: -0.90 | Avg100: -0.04 | Epsilon: 0.0500 | Buffer: 53529
# Episode 1030/10000 | Reward: -9.30 | Avg100: -0.31 | Epsilon: 0.0500 | Buffer: 54029
# Episode 1040/10000 | Reward: 1.50 | Avg100: -0.16 | Epsilon: 0.0500 | Buffer: 54535
# Episode 1050/10000 | Reward: 0.90 | Avg100: -0.00 | Epsilon: 0.0500 | Buffer: 55042
# Episode 1060/10000 | Reward: 2.10 | Avg100: 0.05 | Epsilon: 0.0500 | Buffer: 55556
# Episode 1070/10000 | Reward: -0.90 | Avg100: -0.05 | Epsilon: 0.0500 | Buffer: 56056
# Episode 1080/10000 | Reward: -0.90 | Avg100: 0.01 | Epsilon: 0.0500 | Buffer: 56575
# Episode 1090/10000 | Reward: 1.50 | Avg100: -0.13 | Epsilon: 0.0500 | Buffer: 57103
# Episode 1100/10000 | Reward: -0.90 | Avg100: -0.33 | Epsilon: 0.0500 | Buffer: 57611
# Episode 1110/10000 | Reward: -0.90 | Avg100: -0.18 | Epsilon: 0.0500 | Buffer: 58200
# Episode 1120/10000 | Reward: 2.10 | Avg100: -0.21 | Epsilon: 0.0500 | Buffer: 58752
# Episode 1130/10000 | Reward: -0.30 | Avg100: -0.04 | Epsilon: 0.0500 | Buffer: 59262
# Episode 1140/10000 | Reward: -0.90 | Avg100: -0.11 | Epsilon: 0.0500 | Buffer: 59789
# Episode 1150/10000 | Reward: 0.70 | Avg100: -0.04 | Epsilon: 0.0500 | Buffer: 60343
# Episode 1160/10000 | Reward: 0.80 | Avg100: -0.03 | Epsilon: 0.0500 | Buffer: 60858
# Episode 1170/10000 | Reward: -0.90 | Avg100: 0.17 | Epsilon: 0.0500 | Buffer: 61390
# Episode 1180/10000 | Reward: 2.90 | Avg100: 0.29 | Epsilon: 0.0500 | Buffer: 61902
# Episode 1190/10000 | Reward: 0.10 | Avg100: 0.34 | Epsilon: 0.0500 | Buffer: 62479
# Episode 1200/10000 | Reward: -1.50 | Avg100: 0.44 | Epsilon: 0.0500 | Buffer: 63052
# Episode 1210/10000 | Reward: -1.70 | Avg100: 0.38 | Epsilon: 0.0500 | Buffer: 63622
# Episode 1220/10000 | Reward: -4.50 | Avg100: 0.40 | Epsilon: 0.0500 | Buffer: 64142
# Episode 1230/10000 | Reward: -1.60 | Avg100: 0.51 | Epsilon: 0.0500 | Buffer: 64726
# Episode 1240/10000 | Reward: 2.80 | Avg100: 0.40 | Epsilon: 0.0500 | Buffer: 65254
# Episode 1250/10000 | Reward: 2.70 | Avg100: 0.46 | Epsilon: 0.0500 | Buffer: 65783
# Episode 1260/10000 | Reward: 2.70 | Avg100: 0.40 | Epsilon: 0.0500 | Buffer: 66321
# Episode 1270/10000 | Reward: -0.10 | Avg100: 0.33 | Epsilon: 0.0500 | Buffer: 66948
# Episode 1280/10000 | Reward: 2.70 | Avg100: 0.22 | Epsilon: 0.0500 | Buffer: 67477
# Episode 1290/10000 | Reward: 0.60 | Avg100: 0.17 | Epsilon: 0.0500 | Buffer: 68022
# Episode 1300/10000 | Reward: 0.10 | Avg100: 0.08 | Epsilon: 0.0500 | Buffer: 68600
# Episode 1310/10000 | Reward: -0.90 | Avg100: -0.05 | Epsilon: 0.0500 | Buffer: 69129
# Episode 1320/10000 | Reward: 3.30 | Avg100: 0.08 | Epsilon: 0.0500 | Buffer: 69770
# Episode 1330/10000 | Reward: 2.20 | Avg100: 0.30 | Epsilon: 0.0500 | Buffer: 70387
# Episode 1340/10000 | Reward: 0.60 | Avg100: 0.34 | Epsilon: 0.0500 | Buffer: 71023
# Episode 1350/10000 | Reward: -0.90 | Avg100: 0.24 | Epsilon: 0.0500 | Buffer: 71600
# Episode 1360/10000 | Reward: -0.30 | Avg100: 0.26 | Epsilon: 0.0500 | Buffer: 72137
# Episode 1370/10000 | Reward: 0.00 | Avg100: 0.46 | Epsilon: 0.0500 | Buffer: 72707
# Episode 1380/10000 | Reward: 1.50 | Avg100: 0.71 | Epsilon: 0.0500 | Buffer: 73255
# Episode 1390/10000 | Reward: 2.10 | Avg100: 0.80 | Epsilon: 0.0500 | Buffer: 73869
# Episode 1400/10000 | Reward: -0.90 | Avg100: 0.81 | Epsilon: 0.0500 | Buffer: 74382
# Episode 1410/10000 | Reward: 4.80 | Avg100: 0.88 | Epsilon: 0.0500 | Buffer: 74949
# Episode 1420/10000 | Reward: -0.90 | Avg100: 0.74 | Epsilon: 0.0500 | Buffer: 75642
# Episode 1430/10000 | Reward: 2.40 | Avg100: 0.59 | Epsilon: 0.0500 | Buffer: 76255
# Episode 1440/10000 | Reward: -2.10 | Avg100: 0.73 | Epsilon: 0.0500 | Buffer: 76957
# Episode 1450/10000 | Reward: 3.20 | Avg100: 0.92 | Epsilon: 0.0500 | Buffer: 77554
# Episode 1460/10000 | Reward: 2.90 | Avg100: 1.01 | Epsilon: 0.0500 | Buffer: 78065
# Episode 1470/10000 | Reward: -5.70 | Avg100: 0.84 | Epsilon: 0.0500 | Buffer: 78700
# Episode 1480/10000 | Reward: 4.40 | Avg100: 0.74 | Epsilon: 0.0500 | Buffer: 79310
# Episode 1490/10000 | Reward: 3.40 | Avg100: 0.60 | Epsilon: 0.0500 | Buffer: 79889
# Episode 1500/10000 | Reward: 2.90 | Avg100: 0.81 | Epsilon: 0.0500 | Buffer: 80444
# Episode 1510/10000 | Reward: -0.10 | Avg100: 0.91 | Epsilon: 0.0500 | Buffer: 81107
# Episode 1520/10000 | Reward: -0.90 | Avg100: 0.92 | Epsilon: 0.0500 | Buffer: 81696
# Episode 1530/10000 | Reward: 1.10 | Avg100: 1.05 | Epsilon: 0.0500 | Buffer: 82270
# Episode 1540/10000 | Reward: 3.40 | Avg100: 1.03 | Epsilon: 0.0500 | Buffer: 82854
# Episode 1550/10000 | Reward: 3.30 | Avg100: 0.87 | Epsilon: 0.0500 | Buffer: 83477
# Episode 1560/10000 | Reward: -3.00 | Avg100: 0.81 | Epsilon: 0.0500 | Buffer: 84094
# Episode 1570/10000 | Reward: -0.30 | Avg100: 0.97 | Epsilon: 0.0500 | Buffer: 84664
# Episode 1580/10000 | Reward: 0.20 | Avg100: 1.14 | Epsilon: 0.0500 | Buffer: 85296
# Episode 1590/10000 | Reward: 3.20 | Avg100: 1.37 | Epsilon: 0.0500 | Buffer: 85904
# Episode 1600/10000 | Reward: 2.80 | Avg100: 1.44 | Epsilon: 0.0500 | Buffer: 86499
# Episode 1610/10000 | Reward: -0.90 | Avg100: 1.44 | Epsilon: 0.0500 | Buffer: 87120
# Episode 1620/10000 | Reward: 2.10 | Avg100: 1.50 | Epsilon: 0.0500 | Buffer: 87646
# Episode 1630/10000 | Reward: 6.50 | Avg100: 1.49 | Epsilon: 0.0500 | Buffer: 88386
# Episode 1640/10000 | Reward: 0.30 | Avg100: 1.43 | Epsilon: 0.0500 | Buffer: 88964
# Episode 1650/10000 | Reward: 2.70 | Avg100: 1.37 | Epsilon: 0.0500 | Buffer: 89481
# Episode 1660/10000 | Reward: 1.80 | Avg100: 1.57 | Epsilon: 0.0500 | Buffer: 90034
# Episode 1670/10000 | Reward: 3.00 | Avg100: 1.53 | Epsilon: 0.0500 | Buffer: 90660
# Episode 1680/10000 | Reward: 2.90 | Avg100: 1.32 | Epsilon: 0.0500 | Buffer: 91174
# Episode 1690/10000 | Reward: 2.20 | Avg100: 1.12 | Epsilon: 0.0500 | Buffer: 91735
# Episode 1700/10000 | Reward: 0.50 | Avg100: 1.12 | Epsilon: 0.0500 | Buffer: 92293
# Episode 1710/10000 | Reward: 2.30 | Avg100: 1.07 | Epsilon: 0.0500 | Buffer: 92866
# Episode 1720/10000 | Reward: -0.90 | Avg100: 1.02 | Epsilon: 0.0500 | Buffer: 93388
# Episode 1730/10000 | Reward: 2.10 | Avg100: 0.99 | Epsilon: 0.0500 | Buffer: 93921
# Episode 1740/10000 | Reward: 3.10 | Avg100: 1.06 | Epsilon: 0.0500 | Buffer: 94443
# Episode 1750/10000 | Reward: -0.90 | Avg100: 1.17 | Epsilon: 0.0500 | Buffer: 94960
# Episode 1760/10000 | Reward: 2.60 | Avg100: 1.19 | Epsilon: 0.0500 | Buffer: 95555
# Episode 1770/10000 | Reward: 3.00 | Avg100: 1.27 | Epsilon: 0.0500 | Buffer: 96083
# Episode 1780/10000 | Reward: 2.80 | Avg100: 1.34 | Epsilon: 0.0500 | Buffer: 96595
# Episode 1790/10000 | Reward: 2.70 | Avg100: 1.44 | Epsilon: 0.0500 | Buffer: 97124
# Episode 1800/10000 | Reward: 3.00 | Avg100: 1.30 | Epsilon: 0.0500 | Buffer: 97653
# Episode 1810/10000 | Reward: -0.90 | Avg100: 1.26 | Epsilon: 0.0500 | Buffer: 98168
# Episode 1820/10000 | Reward: -0.90 | Avg100: 1.29 | Epsilon: 0.0500 | Buffer: 98680
# Episode 1830/10000 | Reward: -0.30 | Avg100: 1.23 | Epsilon: 0.0500 | Buffer: 99196
# Episode 1840/10000 | Reward: 2.70 | Avg100: 1.24 | Epsilon: 0.0500 | Buffer: 99719
# Episode 1850/10000 | Reward: -0.90 | Avg100: 1.27 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1860/10000 | Reward: -1.50 | Avg100: 1.19 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1870/10000 | Reward: 0.30 | Avg100: 1.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1880/10000 | Reward: -0.30 | Avg100: 0.94 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1890/10000 | Reward: 2.40 | Avg100: 0.92 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1900/10000 | Reward: 3.00 | Avg100: 0.98 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1910/10000 | Reward: 2.70 | Avg100: 0.99 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1920/10000 | Reward: 2.50 | Avg100: 1.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1930/10000 | Reward: -0.90 | Avg100: 1.04 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1940/10000 | Reward: 3.40 | Avg100: 1.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1950/10000 | Reward: -0.90 | Avg100: 0.90 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1960/10000 | Reward: 2.10 | Avg100: 1.00 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1970/10000 | Reward: -0.90 | Avg100: 1.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1980/10000 | Reward: -0.90 | Avg100: 1.07 | Epsilon: 0.0500 | Buffer: 100000
# Episode 1990/10000 | Reward: 0.30 | Avg100: 1.02 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2000/10000 | Reward: 2.10 | Avg100: 0.98 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2010/10000 | Reward: -0.30 | Avg100: 1.02 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2020/10000 | Reward: 0.90 | Avg100: 0.93 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2030/10000 | Reward: 3.00 | Avg100: 1.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2040/10000 | Reward: -0.90 | Avg100: 0.88 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2050/10000 | Reward: -0.30 | Avg100: 0.96 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2060/10000 | Reward: -0.90 | Avg100: 0.87 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2070/10000 | Reward: -0.90 | Avg100: 0.94 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2080/10000 | Reward: 7.00 | Avg100: 1.03 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2090/10000 | Reward: 0.30 | Avg100: 1.05 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2100/10000 | Reward: -0.90 | Avg100: 1.11 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2110/10000 | Reward: 0.70 | Avg100: 1.07 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2120/10000 | Reward: 1.50 | Avg100: 1.23 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2130/10000 | Reward: 2.50 | Avg100: 1.39 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2140/10000 | Reward: -0.90 | Avg100: 1.43 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2150/10000 | Reward: -0.90 | Avg100: 1.39 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2160/10000 | Reward: 2.10 | Avg100: 1.46 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2170/10000 | Reward: -1.20 | Avg100: 1.42 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2180/10000 | Reward: 1.50 | Avg100: 1.38 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2190/10000 | Reward: 3.70 | Avg100: 1.45 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2200/10000 | Reward: 0.30 | Avg100: 1.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2210/10000 | Reward: 2.80 | Avg100: 1.54 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2220/10000 | Reward: 2.10 | Avg100: 1.57 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2230/10000 | Reward: 2.70 | Avg100: 1.47 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2240/10000 | Reward: -0.90 | Avg100: 1.48 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2250/10000 | Reward: -0.90 | Avg100: 1.47 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2260/10000 | Reward: -0.90 | Avg100: 1.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2270/10000 | Reward: 2.50 | Avg100: 1.50 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2280/10000 | Reward: -0.90 | Avg100: 1.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2290/10000 | Reward: 2.20 | Avg100: 1.48 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2300/10000 | Reward: -0.90 | Avg100: 1.55 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2310/10000 | Reward: 2.90 | Avg100: 1.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2320/10000 | Reward: 2.30 | Avg100: 1.35 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2330/10000 | Reward: 6.50 | Avg100: 1.21 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2340/10000 | Reward: 2.30 | Avg100: 1.24 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2350/10000 | Reward: 4.90 | Avg100: 1.30 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2360/10000 | Reward: 2.40 | Avg100: 1.42 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2370/10000 | Reward: -0.90 | Avg100: 1.51 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2380/10000 | Reward: 3.10 | Avg100: 1.56 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2390/10000 | Reward: 3.10 | Avg100: 1.38 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2400/10000 | Reward: -2.10 | Avg100: 1.24 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2410/10000 | Reward: 3.20 | Avg100: 1.30 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2420/10000 | Reward: 2.40 | Avg100: 1.34 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2430/10000 | Reward: -0.90 | Avg100: 1.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2440/10000 | Reward: 6.00 | Avg100: 1.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2450/10000 | Reward: 4.90 | Avg100: 1.50 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2460/10000 | Reward: 2.90 | Avg100: 1.46 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2470/10000 | Reward: 2.30 | Avg100: 1.37 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2480/10000 | Reward: 2.30 | Avg100: 1.48 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2490/10000 | Reward: -1.50 | Avg100: 1.64 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2500/10000 | Reward: -0.90 | Avg100: 1.67 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2510/10000 | Reward: 2.30 | Avg100: 1.67 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2520/10000 | Reward: 1.40 | Avg100: 1.52 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2530/10000 | Reward: -0.90 | Avg100: 1.40 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2540/10000 | Reward: 2.70 | Avg100: 1.49 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2550/10000 | Reward: -0.90 | Avg100: 1.54 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2560/10000 | Reward: 1.50 | Avg100: 1.42 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2570/10000 | Reward: -0.90 | Avg100: 1.33 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2580/10000 | Reward: 2.70 | Avg100: 1.19 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2590/10000 | Reward: 8.20 | Avg100: 1.17 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2600/10000 | Reward: 2.70 | Avg100: 1.20 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2610/10000 | Reward: -4.50 | Avg100: 1.16 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2620/10000 | Reward: -0.90 | Avg100: 1.29 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2630/10000 | Reward: -0.90 | Avg100: 1.50 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2640/10000 | Reward: 1.90 | Avg100: 1.64 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2650/10000 | Reward: 3.40 | Avg100: 1.62 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2660/10000 | Reward: -0.90 | Avg100: 1.62 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2670/10000 | Reward: -0.90 | Avg100: 1.75 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2680/10000 | Reward: 2.30 | Avg100: 1.70 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2690/10000 | Reward: 4.20 | Avg100: 1.67 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2700/10000 | Reward: -0.90 | Avg100: 1.71 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2710/10000 | Reward: -0.30 | Avg100: 1.76 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2720/10000 | Reward: 4.80 | Avg100: 1.91 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2730/10000 | Reward: 2.80 | Avg100: 1.85 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2740/10000 | Reward: 7.70 | Avg100: 1.71 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2750/10000 | Reward: -0.90 | Avg100: 1.54 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2760/10000 | Reward: -0.90 | Avg100: 1.75 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2770/10000 | Reward: 1.50 | Avg100: 1.82 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2780/10000 | Reward: -0.10 | Avg100: 1.87 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2790/10000 | Reward: 3.90 | Avg100: 1.89 | Epsilon: 0.0500 | Buffer: 100000
# Episode 2800/10000 | Reward: 1.60 | Avg100: 1.77 | Epsilon: 0.0500 | Buffer: 100000
# Episode 
| Epsilon: 0.0500 | Buffer: 100000
# Episode 5550/10000 | Reward: -0.90 | Avg100: 3.38 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5560/10000 | Reward: 15.80 | Avg100: 3.66 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5570/10000 | Reward: 7.60 | Avg100: 3.76 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5580/10000 | Reward: 2.90 | Avg100: 3.76 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5590/10000 | Reward: -0.90 | Avg100: 3.66 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5600/10000 | Reward: 7.60 | Avg100: 3.84 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5610/10000 | Reward: 4.80 | Avg100: 3.82 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5620/10000 | Reward: 6.50 | Avg100: 4.03 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5630/10000 | Reward: 2.60 | Avg100: 4.14 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5640/10000 | Reward: 10.10 | Avg100: 4.17 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5650/10000 | Reward: 2.40 | Avg100: 3.97 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5660/10000 | Reward: -1.10 | Avg100: 3.74 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5670/10000 | Reward: 2.10 | Avg100: 3.62 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5680/10000 | Reward: 5.10 | Avg100: 3.82 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5690/10000 | Reward: 3.20 | Avg100: 3.71 | Epsilon: 0.0500 | Buffer: 100000
# Episode 5700/10000 | Reward: 4.90 | Avg100: 3.50 | Epsilon: 0.0500 | Buffer: 100000
# ...
# Episode 8150/10000 | Reward: 2.10 | Avg100: 3.27 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8160/10000 | Reward: 8.70 | Avg100: 3.42 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8170/10000 | Reward: 13.20 | Avg100: 3.51 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8180/10000 | Reward: 3.60 | Avg100: 3.54 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8190/10000 | Reward: 3.90 | Avg100: 3.54 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8200/10000 | Reward: -1.30 | Avg100: 3.52 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8210/10000 | Reward: 5.50 | Avg100: 3.68 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8220/10000 | Reward: 15.80 | Avg100: 3.79 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8230/10000 | Reward: 3.10 | Avg100: 3.80 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8240/10000 | Reward: 7.20 | Avg100: 3.56 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8250/10000 | Reward: 3.80 | Avg100: 3.33 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8260/10000 | Reward: 7.80 | Avg100: 3.19 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8270/10000 | Reward: -0.40 | Avg100: 3.26 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8280/10000 | Reward: 5.70 | Avg100: 3.14 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8290/10000 | Reward: 1.50 | Avg100: 3.23 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8300/10000 | Reward: 4.90 | Avg100: 3.55 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8310/10000 | Reward: 15.70 | Avg100: 3.54 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8320/10000 | Reward: 5.90 | Avg100: 3.22 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8330/10000 | Reward: -0.90 | Avg100: 3.26 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8340/10000 | Reward: 13.70 | Avg100: 3.47 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8350/10000 | Reward: 4.80 | Avg100: 3.74 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8360/10000 | Reward: 2.20 | Avg100: 3.69 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8370/10000 | Reward: 1.70 | Avg100: 3.24 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8380/10000 | Reward: 5.70 | Avg100: 3.60 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8390/10000 | Reward: 4.30 | Avg100: 3.59 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8400/10000 | Reward: 4.60 | Avg100: 3.44 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8410/10000 | Reward: -0.90 | Avg100: 3.50 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8420/10000 | Reward: -7.50 | Avg100: 3.69 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8430/10000 | Reward: 0.30 | Avg100: 3.69 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8440/10000 | Reward: 2.70 | Avg100: 3.55 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8450/10000 | Reward: -0.30 | Avg100: 3.66 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8460/10000 | Reward: 6.30 | Avg100: 3.86 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8470/10000 | Reward: 3.30 | Avg100: 4.05 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8480/10000 | Reward: 12.50 | Avg100: 3.86 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8490/10000 | Reward: 1.90 | Avg100: 3.72 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8500/10000 | Reward: 7.10 | Avg100: 3.72 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8510/10000 | Reward: -0.90 | Avg100: 3.81 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8520/10000 | Reward: 9.40 | Avg100: 4.03 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8530/10000 | Reward: 3.00 | Avg100: 4.05 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8540/10000 | Reward: -0.90 | Avg100: 4.17 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8550/10000 | Reward: 2.30 | Avg100: 4.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8560/10000 | Reward: 7.40 | Avg100: 3.90 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8570/10000 | Reward: 7.10 | Avg100: 4.00 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8580/10000 | Reward: 5.90 | Avg100: 4.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8590/10000 | Reward: 2.50 | Avg100: 4.13 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8600/10000 | Reward: 9.40 | Avg100: 4.49 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8610/10000 | Reward: -0.90 | Avg100: 4.35 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8620/10000 | Reward: 5.80 | Avg100: 4.20 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8630/10000 | Reward: 3.90 | Avg100: 4.13 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8640/10000 | Reward: -0.90 | Avg100: 4.23 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8650/10000 | Reward: -0.90 | Avg100: 4.25 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8660/10000 | Reward: 4.40 | Avg100: 4.32 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8670/10000 | Reward: -0.90 | Avg100: 4.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8680/10000 | Reward: -2.80 | Avg100: 3.98 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8690/10000 | Reward: 17.80 | Avg100: 4.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8700/10000 | Reward: 5.90 | Avg100: 4.23 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8710/10000 | Reward: -0.90 | Avg100: 4.29 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8720/10000 | Reward: 1.30 | Avg100: 4.34 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8730/10000 | Reward: 3.90 | Avg100: 4.39 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8740/10000 | Reward: -3.30 | Avg100: 4.13 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8750/10000 | Reward: -0.20 | Avg100: 3.91 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8760/10000 | Reward: 2.80 | Avg100: 3.83 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8770/10000 | Reward: 2.50 | Avg100: 4.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8780/10000 | Reward: 5.90 | Avg100: 3.99 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8790/10000 | Reward: -3.60 | Avg100: 3.40 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8800/10000 | Reward: 4.70 | Avg100: 3.20 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8810/10000 | Reward: -0.90 | Avg100: 3.50 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8820/10000 | Reward: 0.20 | Avg100: 3.43 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8830/10000 | Reward: 0.90 | Avg100: 3.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8840/10000 | Reward: -0.90 | Avg100: 3.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8850/10000 | Reward: 10.40 | Avg100: 3.40 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8860/10000 | Reward: 5.30 | Avg100: 3.26 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8870/10000 | Reward: 13.40 | Avg100: 3.49 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8880/10000 | Reward: 1.80 | Avg100: 3.55 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8890/10000 | Reward: 6.50 | Avg100: 3.98 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8900/10000 | Reward: 4.20 | Avg100: 4.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8910/10000 | Reward: -0.30 | Avg100: 3.58 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8920/10000 | Reward: -0.90 | Avg100: 3.60 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8930/10000 | Reward: 3.80 | Avg100: 3.66 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8940/10000 | Reward: 2.40 | Avg100: 3.69 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8950/10000 | Reward: 4.30 | Avg100: 3.95 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8960/10000 | Reward: -0.90 | Avg100: 3.92 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8970/10000 | Reward: 3.20 | Avg100: 3.86 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8980/10000 | Reward: 2.70 | Avg100: 3.88 | Epsilon: 0.0500 | Buffer: 100000
# Episode 8990/10000 | Reward: 12.20 | Avg100: 3.69 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9000/10000 | Reward: 5.20 | Avg100: 3.90 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9010/10000 | Reward: 5.20 | Avg100: 3.86 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9020/10000 | Reward: 0.90 | Avg100: 4.07 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9030/10000 | Reward: -0.90 | Avg100: 3.93 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9040/10000 | Reward: -0.90 | Avg100: 3.81 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9050/10000 | Reward: 0.30 | Avg100: 3.93 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9060/10000 | Reward: 4.40 | Avg100: 4.21 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9070/10000 | Reward: 13.90 | Avg100: 4.27 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9080/10000 | Reward: 2.00 | Avg100: 4.18 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9090/10000 | Reward: 8.90 | Avg100: 4.43 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9100/10000 | Reward: 3.30 | Avg100: 4.35 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9110/10000 | Reward: 3.00 | Avg100: 4.60 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9120/10000 | Reward: 4.80 | Avg100: 4.60 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9130/10000 | Reward: -0.30 | Avg100: 4.73 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9140/10000 | Reward: -0.90 | Avg100: 4.67 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9150/10000 | Reward: 3.10 | Avg100: 4.38 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9160/10000 | Reward: 8.90 | Avg100: 4.21 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9170/10000 | Reward: -0.90 | Avg100: 4.28 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9180/10000 | Reward: 4.20 | Avg100: 4.30 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9190/10000 | Reward: 4.10 | Avg100: 3.79 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9200/10000 | Reward: 0.50 | Avg100: 3.53 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9210/10000 | Reward: -0.90 | Avg100: 3.42 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9220/10000 | Reward: 5.90 | Avg100: 3.25 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9230/10000 | Reward: -0.90 | Avg100: 3.12 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9240/10000 | Reward: -0.90 | Avg100: 3.29 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9250/10000 | Reward: 9.80 | Avg100: 3.37 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9260/10000 | Reward: 3.30 | Avg100: 3.45 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9270/10000 | Reward: 3.00 | Avg100: 3.11 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9280/10000 | Reward: -0.30 | Avg100: 3.16 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9290/10000 | Reward: -0.90 | Avg100: 3.36 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9300/10000 | Reward: -0.90 | Avg100: 3.79 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9310/10000 | Reward: -0.90 | Avg100: 3.72 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9320/10000 | Reward: -0.90 | Avg100: 3.54 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9330/10000 | Reward: 3.40 | Avg100: 3.58 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9340/10000 | Reward: 2.90 | Avg100: 3.62 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9350/10000 | Reward: -0.90 | Avg100: 3.56 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9360/10000 | Reward: 8.60 | Avg100: 3.68 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9370/10000 | Reward: -0.90 | Avg100: 3.87 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9380/10000 | Reward: -1.50 | Avg100: 3.89 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9390/10000 | Reward: 2.30 | Avg100: 4.09 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9400/10000 | Reward: -0.60 | Avg100: 3.80 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9410/10000 | Reward: 1.50 | Avg100: 3.93 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9420/10000 | Reward: 5.30 | Avg100: 4.06 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9430/10000 | Reward: -0.90 | Avg100: 4.16 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9440/10000 | Reward: 13.60 | Avg100: 4.13 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9450/10000 | Reward: -0.90 | Avg100: 3.94 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9460/10000 | Reward: 3.00 | Avg100: 3.85 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9470/10000 | Reward: 1.20 | Avg100: 3.87 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9480/10000 | Reward: 4.10 | Avg100: 4.50 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9490/10000 | Reward: 5.80 | Avg100: 4.56 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9500/10000 | Reward: 6.20 | Avg100: 4.67 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9510/10000 | Reward: 9.40 | Avg100: 4.61 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9520/10000 | Reward: 5.10 | Avg100: 4.51 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9530/10000 | Reward: -0.90 | Avg100: 4.16 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9540/10000 | Reward: 5.20 | Avg100: 4.21 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9550/10000 | Reward: 10.20 | Avg100: 4.44 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9560/10000 | Reward: 0.30 | Avg100: 4.44 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9570/10000 | Reward: 2.10 | Avg100: 4.27 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9580/10000 | Reward: 5.90 | Avg100: 3.98 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9590/10000 | Reward: 3.00 | Avg100: 3.60 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9600/10000 | Reward: 5.70 | Avg100: 3.30 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9610/10000 | Reward: 3.00 | Avg100: 3.40 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9620/10000 | Reward: 7.80 | Avg100: 3.58 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9630/10000 | Reward: 1.80 | Avg100: 3.86 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9640/10000 | Reward: 31.00 | Avg100: 4.04 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9650/10000 | Reward: 8.80 | Avg100: 4.31 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9660/10000 | Reward: 10.00 | Avg100: 4.25 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9670/10000 | Reward: -0.90 | Avg100: 4.35 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9680/10000 | Reward: 1.70 | Avg100: 3.89 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9690/10000 | Reward: -0.90 | Avg100: 4.06 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9700/10000 | Reward: 9.00 | Avg100: 4.47 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9710/10000 | Reward: 6.50 | Avg100: 4.52 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9720/10000 | Reward: -1.50 | Avg100: 4.69 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9730/10000 | Reward: -0.90 | Avg100: 4.79 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9740/10000 | Reward: 16.20 | Avg100: 4.80 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9750/10000 | Reward: -0.90 | Avg100: 4.41 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9760/10000 | Reward: 1.70 | Avg100: 4.62 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9770/10000 | Reward: 12.50 | Avg100: 4.66 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9780/10000 | Reward: 6.20 | Avg100: 4.93 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9790/10000 | Reward: 11.10 | Avg100: 4.77 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9800/10000 | Reward: 5.10 | Avg100: 4.51 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9810/10000 | Reward: -1.80 | Avg100: 4.12 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9820/10000 | Reward: 6.90 | Avg100: 4.07 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9830/10000 | Reward: 5.90 | Avg100: 4.22 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9840/10000 | Reward: 2.70 | Avg100: 4.06 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9850/10000 | Reward: 9.70 | Avg100: 4.20 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9860/10000 | Reward: 3.60 | Avg100: 4.07 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9870/10000 | Reward: 3.30 | Avg100: 4.43 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9880/10000 | Reward: 4.70 | Avg100: 4.29 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9890/10000 | Reward: 14.70 | Avg100: 4.55 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9900/10000 | Reward: 9.50 | Avg100: 4.80 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9910/10000 | Reward: 2.00 | Avg100: 5.20 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9920/10000 | Reward: 4.80 | Avg100: 5.01 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9930/10000 | Reward: 4.20 | Avg100: 4.58 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9940/10000 | Reward: 3.00 | Avg100: 4.58 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9950/10000 | Reward: 3.60 | Avg100: 4.94 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9960/10000 | Reward: 2.60 | Avg100: 4.84 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9970/10000 | Reward: -0.90 | Avg100: 4.65 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9980/10000 | Reward: 6.20 | Avg100: 4.80 | Epsilon: 0.0500 | Buffer: 100000
# Episode 9990/10000 | Reward: 6.80 | Avg100: 4.89 | Epsilon: 0.0500 | Buffer: 100000
# Episode 10000/10000 | Reward: -0.30 | Avg100: 4.78 | Epsilon: 0.0500 | Buffer: 100000
# Recorded episode 1/10
# Recorded episode 2/10
# Recorded episode 3/10
# Recorded episode 4/10
# Recorded episode 5/10
# Recorded episode 6/10
# Recorded episode 7/10
# Recorded episode 8/10
# Recorded episode 9/10
# Recorded episode 10/10
# Saved compiled video to videos\flappy_state_trained.mp4

# %%
def record_best_dueling_dqn_videos(
    env_name='FlappyBird-v0',
    model_path='best_flappy_dqn_state.pth',
    output_dir='videos',
    output_filename='flappybird_best10.mp4',
    frame_stack_k=3,
    num_eval_episodes=30,
    top_k=10,
    max_steps=500
):
    os.makedirs(output_dir, exist_ok=True)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    env = gym.make(env_name, render_mode='rgb_array')
    state_dim = len(env.reset()[0]) * frame_stack_k
    action_dim = env.action_space.n

    # Load trained model
    model = DuelingDQN(state_dim, action_dim).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    results = []  # (reward, frames)
    print(f"Evaluating {num_eval_episodes} episodes to pick best {top_k}...")

    for ep in range(num_eval_episodes):
        obs, _ = env.reset()
        frame_deque = deque(maxlen=frame_stack_k)
        state = stack_frames(frame_deque, obs, frame_stack_k)
        done, total_reward, step = False, 0, 0
        frames = []

        while not done and step < max_steps:
            with torch.no_grad():
                q_values = model(torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0))
                action = torch.argmax(q_values, dim=1).item()

            obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            frame_deque.append(obs)
            state = np.concatenate(list(frame_deque), axis=-1)
            frames.append(env.render())
            total_reward += reward
            step += 1

        results.append((total_reward, frames))
        print(f"Episode {ep+1}/{num_eval_episodes} | Reward: {total_reward:.2f}")

    env.close()

    # Pick best episodes
    results.sort(key=lambda x: x[0], reverse=True)
    best_episodes = results[:top_k]
    print(f"Saving top {top_k} episodes merged into one video...")

    merged_path = os.path.join(output_dir, output_filename)
    writer = imageio.get_writer(merged_path, fps=30)

    for i, (reward, frames) in enumerate(best_episodes, 1):
        for frame in frames:
            writer.append_data(frame)
        print(f"Added episode {i} (Reward: {reward:.2f})")

    writer.close()
    print(f"\n Saved merged video at: {merged_path}")

# Run it
record_best_dueling_dqn_videos()
# Out:
# Evaluating 30 episodes to pick best 10...
# C:\Users\tj\AppData\Local\Temp\ipykernel_22932\3761853252.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Episode 1/30 | Reward: 49.40
# Episode 2/30 | Reward: 48.20
# Episode 3/30 | Reward: 44.60
# Episode 4/30 | Reward: 47.00
# Episode 5/30 | Reward: 47.60
# Episode 6/30 | Reward: 45.80
# Episode 7/30 | Reward: 44.00
# Episode 8/30 | Reward: 47.60
# Episode 9/30 | Reward: 31.40
# Episode 10/30 | Reward: 50.00
# Episode 11/30 | Reward: 14.20
# Episode 12/30 | Reward: 17.50
# Episode 13/30 | Reward: 49.40
# Episode 14/30 | Reward: 47.00
# Episode 15/30 | Reward: 46.40
# Episode 16/30 | Reward: 50.60
# Episode 17/30 | Reward: 41.00
# Episode 18/30 | Reward: 44.00
# Episode 19/30 | Reward: 45.80
# Episode 20/30 | Reward: 48.80
# Episode 21/30 | Reward: 45.20
# Episode 22/30 | Reward: 48.20
# Episode 23/30 | Reward: 46.40
# Episode 24/30 | Reward: 45.20
# Episode 25/30 | Reward: 47.00
# Episode 26/30 | Reward: 46.40
# Episode 27/30 | Reward: 50.00
# Episode 28/30 | Reward: 9.50
# Episode 29/30 | Reward: 33.00
# Episode 30/30 | Reward: 48.80
# Saving top 10 episodes merged into one video...
# Added episode 1 (Reward: 50.60)
# Added episode 2 (Reward: 50.00)
# Added episode 3 (Reward: 50.00)
# Added episode 4 (Reward: 49.40)
# Added episode 5 (Reward: 49.40)
# Added episode 6 (Reward: 48.80)
# Added episode 7 (Reward: 48.80)
# Added episode 8 (Reward: 48.20)
# Added episode 9 (Reward: 48.20)
# Added episode 10 (Reward: 47.60)
#
#  Saved merged video at: videos\flappybird_best10.mp4

# %%
display(Video("videos/flappybird_best10.mp4", embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
